# %%
import pandas as pd
import datetime as dt
import re
import functools as fc

# %%
countries = pd.read_csv(r'C:\UfoProject\data\countries.csv',sep=';')

# %%
dataframe = pd.read_csv(r'C:\UfoProject\data\complete.csv',sep=',',on_bad_lines='warn')
# Out:
# C:\Users\grant\AppData\Local\Temp\ipykernel_5148\291033062.py:1: ParserWarning: Skipping line 878: expected 11 fields, saw 12
# Skipping line 1713: expected 11 fields, saw 12
# Skipping line 1815: expected 11 fields, saw 12
# Skipping line 2858: expected 11 fields, saw 12
# Skipping line 3734: expected 11 fields, saw 12
# Skipping line 4756: expected 11 fields, saw 12
# Skipping line 5389: expected 11 fields, saw 12
# Skipping line 5423: expected 11 fields, saw 12
# Skipping line 5614: expected 11 fields, saw 12
# Skipping line 5849: expected 11 fields, saw 12
# Skipping line 6093: expected 11 fields, saw 12
# Skipping line 7516: expected 11 fields, saw 12
# Skipping line 7626: expected 11 fields, saw 12
# Skipping line 8893: expected 11 fields, saw 12
# Skipping line 9015: expected 11 fields, saw 12
# Skipping line 9571: expected 11 fields, saw 12
# Skipping line 9620: expected 11 fields, saw 12
# Skipping line 9751: expected 11 fields, saw 12
# Skipping line 10157: expected 11 fields, saw 12
# Skipping line 10427: expected 11 fields, saw 12
# Skipping line 12035: expected 11 fields, saw 12
# Skipping line 12113: expected 11 fields, saw 12
# Skipping line 12144: expected 11 fields, saw 12
# Skipping line 12891: expected 11 fields, saw 12
# Skipping line 14613: expected 11 fields, saw 12
# Skipping line 16031: expected 11 fields, saw 12
# Skipping line 16344: expected 11 fields, saw 12
# Skipping line 16399: expected 11 fields, saw 12
# Skipping line 16635: expected 11 fields, saw 12
# Skipping line 16722: expected 11 fields, saw 12
# Skipping line 18241: expected 11 fields, saw 12
# Skipping line 18367: expected 11 fields, saw 12
# Skipping line 18479: expected 11 fields, saw 12
# Skipping line 19814: expected 11 fields, saw 12
# Skipping line 19859: expected 11 fields, saw 12
# Skipping line 19909: expected 11 fields, saw 12
# Skipping line 19935: expected 11 fields, saw 12
# Skipping line 20386: expected 11 fields, saw 12
# Skipping line 20533: expected 11 fields, saw 12
# Skipping line 20764: expected 11 fields, saw 12
# Skipping line 21145: expected 11 fields, saw 12
# Skipping line 21291: expected 11 fields, saw 12
# Skipping line 21309: expected 11 fields, saw 12
# Skipping line 21576: expected 11 fields, saw 12
# Skipping line 21966: expected 11 fields, saw 12
# Skipping line 22092: expected 11 fields, saw 12
# Skipping line 22108: expected 11 fields, saw 12
# Skipping line 22236: expected 11 fields, saw 12
# Skipping line 22785: expected 11 fields, saw 12
# Skipping line 23143: expected 11 fields, saw 12
# Skipping line 23145: expected 11 fields, saw 12
# Skipping line 23251: expected 11 fields, saw 12
# Skipping line 23369: expected 11 fields, saw 12
# Skipping line 23464: expected 11 fields, saw 12
# Skipping line 23622: expected 11 fields, saw 12
# Skipping line 23732: expected 11 fields, saw 12
# Skipping line 23924: expected 11 fields, saw 12
# Skipping line 24696: expected 11 fields, saw 12
# Skipping line 25543: expected 11 fields, saw 12
# Skipping line 25703: expected 11 fields, saw 12
# Skipping line 25815: expected 11 fields, saw 12
# Skipping line 26185: expected 11 fields, saw 12
# Skipping line 27424: expected 11 fields, saw 12
# Skipping line 27465: expected 11 fields, saw 12
# Skipping line 28083: expected 11 fields, saw 12
# Skipping line 28282: expected 11 fields, saw 12
# Skipping line 28460: expected 11 fields, saw 12
# Skipping line 28745: expected 11 fields, saw 12
# Skipping line 29674: expected 11 fields, saw 12
# Skipping line 30342: expected 11 fields, saw 12
# Skipping line 30417: expected 11 fields, saw 12
# Skipping line 31154: expected 11 fields, saw 12
# Skipping line 31308: expected 11 fields, saw 12
# Skipping line 32198: expected 11 fields, saw 12
# Skipping line 32439: expected 11 fields, saw 12
# Skipping line 32675: expected 11 fields, saw 12
# Skipping line 33134: expected 11 fields, saw 12
# Skipping line 33442: expected 11 fields, saw 12
# Skipping line 34184: expected 11 fields, saw 12
# Skipping line 34731: expected 11 fields, saw 12
# Skipping line 34869: expected 11 fields, saw 12
# Skipping line 35107: expected 11 fields, saw 12
# Skipping line 35300: expected 11 fields, saw 12
# Skipping line 35396: expected 11 fields, saw 12
# Skipping line 35913: expected 11 fields, saw 12
# Skipping line 36445: expected 11 fields, saw 12
# Skipping line 36693: expected 11 fields, saw 12
# Skipping line 36723: expected 11 fields, saw 12
# Skipping line 37293: expected 11 fields, saw 12
# Skipping line 37361: expected 11 fields, saw 12
# Skipping line 37980: expected 11 fields, saw 12
# Skipping line 38090: expected 11 fields, saw 12
# Skipping line 38197: expected 11 fields, saw 12
# Skipping line 39431: expected 11 fields, saw 12
# Skipping line 39598: expected 11 fields, saw 12
# Skipping line 39679: expected 11 fields, saw 12
# Skipping line 39794: expected 11 fields, saw 12
# Skipping line 40021: expected 11 fields, saw 12
# Skipping line 40430: expected 11 fields, saw 12
# Skipping line 42858: expected 11 fields, saw 12
# Skipping line 43662: expected 11 fields, saw 12
# Skipping line 44162: expected 11 fields, saw 12
# Skipping line 45529: expected 11 fields, saw 12
# Skipping line 46678: expected 11 fields, saw 12
# Skipping line 46788: expected 11 fields, saw 12
# Skipping line 46811: expected 11 fields, saw 12
# Skipping line 46924: expected 11 fields, saw 12
# Skipping line 47287: expected 11 fields, saw 12
# Skipping line 47377: expected 11 fields, saw 12
# Skipping line 47419: expected 11 fields, saw 12
# Skipping line 47492: expected 11 fields, saw 12
# Skipping line 47629: expected 11 fields, saw 12
# Skipping line 48125: expected 11 fields, saw 12
# Skipping line 48932: expected 11 fields, saw 12
# Skipping line 48971: expected 11 fields, saw 12
# Skipping line 49440: expected 11 fields, saw 12
# Skipping line 49457: expected 11 fields, saw 12
# Skipping line 50670: expected 11 fields, saw 12
# Skipping line 50960: expected 11 fields, saw 12
# Skipping line 51275: expected 11 fields, saw 12
# Skipping line 51649: expected 11 fields, saw 12
# Skipping line 51993: expected 11 fields, saw 12
# Skipping line 52023: expected 11 fields, saw 12
# Skipping line 52059: expected 11 fields, saw 12
# Skipping line 52259: expected 11 fields, saw 12
# Skipping line 52368: expected 11 fields, saw 12
# Skipping line 52783: expected 11 fields, saw 12
# Skipping line 53064: expected 11 fields, saw 12
# Skipping line 53135: expected 11 fields, saw 12
# Skipping line 53514: expected 11 fields, saw 12
# Skipping line 54092: expected 11 fields, saw 12
# Skipping line 55403: expected 11 fields, saw 12
# Skipping line 57476: expected 11 fields, saw 12
# Skipping line 58646: expected 11 fields, saw 12
# Skipping line 58808: expected 11 fields, saw 12
# Skipping line 59119: expected 11 fields, saw 12
# Skipping line 59727: expected 11 fields, saw 12
# Skipping line 60386: expected 11 fields, saw 12
# Skipping line 60478: expected 11 fields, saw 12
# Skipping line 60542: expected 11 fields, saw 12
# Skipping line 60913: expected 11 fields, saw 12
# Skipping line 61032: expected 11 fields, saw 12
# Skipping line 61640: expected 11 fields, saw 12
# Skipping line 61732: expected 11 fields, saw 12
# Skipping line 62029: expected 11 fields, saw 12
# Skipping line 62219: expected 11 fields, saw 12
# Skipping line 63657: expected 11 fields, saw 12
# Skipping line 64712: expected 11 fields, saw 12
#
#   dataframe = pd.read_csv(r'C:\UfoProject\data\complete.csv',sep=',',on_bad_lines='warn')
# C:\Users\grant\AppData\Local\Temp\ipykernel_5148\291033062.py:1: ParserWarning: Skipping line 65881: expected 11 fields, saw 12
# Skipping line 66093: expected 11 fields, saw 12
# Skipping line 66095: expected 11 fields, saw 12
# Skipping line 66476: expected 11 fields, saw 12
# Skipping line 66549: expected 11 fields, saw 12
# Skipping line 66550: expected 11 fields, saw 12
# Skipping line 68102: expected 11 fields, saw 12
# Skipping line 69441: expected 11 fields, saw 12
# Skipping line 70104: expected 11 fields, saw 12
# Skipping line 70452: expected 11 fields, saw 12
# Skipping line 70642: expected 11 fields, saw 12
# Skipping line 70644: expected 11 fields, saw 12
# Skipping line 70716: expected 11 fields, saw 12
# Skipping line 71345: expected 11 fields, saw 12
# Skipping line 71634: expected 11 fields, saw 12
# Skipping line 72091: expected 11 fields, saw 12
# Skipping line 72119: expected 11 fields, saw 12
# Skipping line 73543: expected 11 fields, saw 12
# Skipping line 74654: expected 11 fields, saw 12
# Skipping line 74785: expected 11 fields, saw 12
# Skipping line 74918: expected 11 fields, saw 12
# Skipping line 75062: expected 11 fields, saw 12
# Skipping line 75346: expected 11 fields, saw 12
# Skipping line 75416: expected 11 fields, saw 12
# Skipping line 75677: expected 11 fields, saw 12
# Skipping line 75833: expected 11 fields, saw 12
# Skipping line 76117: expected 11 fields, saw 12
# Skipping line 76834: expected 11 fields, saw 12
# Skipping line 77540: expected 11 fields, saw 12
# Skipping line 77568: expected 11 fields, saw 12
# Skipping line 77607: expected 11 fields, saw 12
# Skipping line 77871: expected 11 fields, saw 12
# Skipping line 78117: expected 11 fields, saw 12
# Skipping line 78526: expected 11 fields, saw 12
# Skipping line 78605: expected 11 fields, saw 12
# Skipping line 79151: expected 11 fields, saw 12
# Skipping line 79945: expected 11 fields, saw 12
# Skipping line 80156: expected 11 fields, saw 12
# Skipping line 80328: expected 11 fields, saw 12
# Skipping line 80382: expected 11 fields, saw 12
# Skipping line 80421: expected 11 fields, saw 12
# Skipping line 80503: expected 11 fields, saw 12
# Skipping line 82071: expected 11 fields, saw 12
# Skipping line 82566: expected 11 fields, saw 12
# Skipping line 86123: expected 11 fields, saw 12
# Skipping line 87218: expected 11 fields, saw 12
# Skipping line 87457: expected 11 fields, saw 12
# Skipping line 87579: expected 11 fields, saw 12
#
#   dataframe = pd.read_csv(r'C:\UfoProject\data\complete.csv',sep=',',on_bad_lines='warn')
# C:\Users\grant\AppData\Local\Temp\ipykernel_5148\291033062.py:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframe = pd.read_csv(r'C:\UfoProject\data\complete.csv',sep=',',on_bad_lines='warn')

# %%
dataframe.head(5)
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#     longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
dataframe.dtypes
# Out:
# datetime                 object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)       object
# duration (hours/min)     object
# comments                 object
# date posted              object
# latitude                 object
# longitude               float64
# dtype: object

# %%
dataframe['date_changes'] = dataframe['datetime'].str.split(" ")

# %%
dataframe['new_date'] = dataframe['date_changes'].apply(lambda a: a[0])
dataframe['new_hour'] = dataframe['date_changes'].apply(lambda a: a[1])

# %%
dataframe.head(5)
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#     longitude         date_changes    new_date new_hour
# 0  -97.941111  [10/10/1949, 20:30]  10/10/1949    20:30
# 1  -98.581082  [10/10/1949, 21:00]  10/10/1949    21:00
# 2   -2.916667  [10/10/1955, 17:00]  10/10/1955    17:00
# 3  -96.645833  [10/10/1956, 21:00]  10/10/1956    21:00
# 4 -157.803611  [10/10/1960, 20:00]  10/10/1960    20:00

# %%
dataframe['new_hour'] = dataframe['new_hour'].apply(lambda a: a + ':00')

# %%
dataframe['new_date'] = dataframe['new_date'].astype('datetime64[ns]')
dataframe['new_hour'] = dataframe['new_hour'].astype('timedelta64[ns]')

# %%
dataframe.head(5)
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#     longitude         date_changes   new_date        new_hour
# 0  -97.941111  [10/10/1949, 20:30] 1949-10-10 0 days 20:30:00
# 1  -98.581082  [10/10/1949, 21:00] 1949-10-10 0 days 21:00:00
# 2   -2.916667  [10/10/1955, 17:00] 1955-10-10 0 days 17:00:00
# 3  -96.645833  [10/10/1956, 21:00] 1956-10-10 0 days 21:00:00
# 4 -157.803611  [10/10/1960, 20:00] 1960-10-10 0 days 20:00:00

# %%
dataframe.dtypes
# Out:
# datetime                         object
# city                             object
# state                            object
# country                          object
# shape                            object
# duration (seconds)               object
# duration (hours/min)             object
# comments                         object
# date posted                      object
# latitude                         object
# longitude                       float64
# date_changes                     object
# new_date                 datetime64[ns]
# new_hour                timedelta64[ns]
# dtype: object

# %%
dataframe['hour_cleaned'] = dataframe['new_hour'].mask(dataframe['new_hour'] >= dt.timedelta(hours=24), dataframe['new_hour'] - dt.timedelta(hours=24))

# %%
dataframe.head(5)
# Out:
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...   4/27/2004  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...   1/21/2008        53.2
# 3  My older brother and twin sister were leaving ...   1/17/2004  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4180556
#
#     longitude         date_changes   new_date        new_hour    hour_cleaned
# 0  -97.941111  [10/10/1949, 20:30] 1949-10-10 0 days 20:30:00 0 days 20:30:00
# 1  -98.581082  [10/10/1949, 21:00] 1949-10-10 0 days 21:00:00 0 days 21:00:00
# 2   -2.916667  [10/10/1955, 17:00] 1955-10-10 0 days 17:00:00 0 days 17:00:00
# 3  -96.645833  [10/10/1956, 21:00] 1956-10-10 0 days 21:00:00 0 days 21:00:00
# 4 -157.803611  [10/10/1960, 20:00] 1960-10-10 0 days 20:00:00 0 days 20:00:00

# %%
dataframe['final_date'] = dataframe['new_date'] + dataframe['hour_cleaned']

# %%
dataframe['datetime'] = dataframe['final_date']

# %%
dataframe = dataframe.drop(columns = ['date_changes','new_date','new_hour','hour_cleaned','final_date'])

# %%
dataframe.dtypes
# Out:
# datetime                datetime64[ns]
# city                            object
# state                           object
# country                         object
# shape                           object
# duration (seconds)              object
# duration (hours/min)            object
# comments                        object
# date posted                     object
# latitude                        object
# longitude                      float64
# dtype: object

# %%
dataframe['comments'] = dataframe['comments'].astype('str')

# %%
dataframe['date posted'] = dataframe['date posted'].astype('datetime64[ns]')
dataframe['comments'] = dataframe['comments'].astype('str')

# %%
dataframe.head(5)
# Out:
#              datetime                  city state country     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3 1956-10-10 21:00:00                  edna    tx      us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
#                                             comments date posted    latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.8830556
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16    29.38421
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21        53.2
# 3  My older brother and twin sister were leaving ...  2004-01-17  28.9783333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.4180556
#
#     longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
dataframe.dtypes
# Out:
# datetime                datetime64[ns]
# city                            object
# state                           object
# country                         object
# shape                           object
# duration (seconds)              object
# duration (hours/min)            object
# comments                        object
# date posted             datetime64[ns]
# latitude                        object
# longitude                      float64
# dtype: object

# %%
dataframe['latitude'] = dataframe['latitude'].astype('str')
dataframe['latitude'] = dataframe['latitude'].str.strip()
dataframe['lat_splited'] = dataframe['latitude'].str.split('')

# %%
dataframe.tail(10)
# Out:
#                  datetime             city state country     shape  \
# 88669 2013-09-09 21:00:00  milton (canada)    on      ca  fireball
# 88670 2013-09-09 21:00:00        woodstock    ga      us    sphere
# 88671 2013-09-09 21:15:00        nashville    tn      us     light
# 88672 2013-09-09 22:00:00            boise    id      us    circle
# 88673 2013-09-09 22:00:00        kalispell    mt      us      disk
# 88674 2013-09-09 22:00:00             napa    ca      us     other
# 88675 2013-09-09 22:20:00           vienna    va      us    circle
# 88676 2013-09-09 23:00:00           edmond    ok      us     cigar
# 88677 2013-09-09 23:00:00            starr    sc      us   diamond
# 88678 2013-09-09 23:30:00   ft. lauderdale    fl      us      oval
#
#       duration (seconds) duration (hours/min)  \
# 88669              180.0            3 minutes
# 88670               20.0           20 seconds
# 88671              600.0           10 minutes
# 88672             1200.0           20 minutes
# 88673                0.0           continuing
# 88674             1200.0                 hour
# 88675                5.0            5 seconds
# 88676             1020.0           17 minutes
# 88677                0.0             2 nights
# 88678                0.0       still occuring
#
#                                                 comments date posted  \
# 88669              Massive Bright Orange Fireball in Sky  2013-09-30
# 88670  Driving 575 at 21:00 hrs saw a white and green...  2013-09-30
# 88671  Round from the distance/slowly changing colors...  2013-09-30
# 88672  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...  2013-09-30
# 88673  I was letting my dogs our for the night when I...  2013-09-30
# 88674                                       Napa UFO&#44  2013-09-30
# 88675  Saw a five gold lit cicular craft moving fastl...  2013-09-30
# 88676  2 witnesses 2  miles apart&#44 Red &amp; White...  2013-09-30
# 88677  On September ninth my wife and i noticed stran...  2013-09-30
# 88678  Hovering object lit with red and white lights&...  2013-09-30
#
#          latitude   longitude                         lat_splited
# 88669        46.3  -63.216667                    [, 4, 6, ., 3, ]
# 88670  34.1013889  -84.519444  [, 3, 4, ., 1, 0, 1, 3, 8, 8, 9, ]
# 88671  36.1658333  -86.784444  [, 3, 6, ., 1, 6, 5, 8, 3, 3, 3, ]
# 88672  43.6136111 -116.202500  [, 4, 3, ., 6, 1, 3, 6, 1, 1, 1, ]
# 88673  48.1958333 -114.311944  [, 4, 8, ., 1, 9, 5, 8, 3, 3, 3, ]
# 88674  38.2972222 -122.284444  [, 3, 8, ., 2, 9, 7, 2, 2, 2, 2, ]
# 88675  38.9011111  -77.265556  [, 3, 8, ., 9, 0, 1, 1, 1, 1, 1, ]
# 88676  35.6527778  -97.477778  [, 3, 5, ., 6, 5, 2, 7, 7, 7, 8, ]
# 88677  34.3769444  -82.695833  [, 3, 4, ., 3, 7, 6, 9, 4, 4, 4, ]
# 88678  26.1219444  -80.143611  [, 2, 6, ., 1, 2, 1, 9, 4, 4, 4, ]

# %%
def regex_match(a):
    if re.search("[0123456789,.]", a):
        return True
    else:
        return False

dataframe['lat_filtered'] = dataframe['lat_splited'].apply(
    lambda x: list(filter(
        lambda a:  regex_match(a),x
    ))
)

# %%
dataframe['lat_final'] = dataframe['lat_filtered'].apply(
    lambda x: fc.reduce(
        lambda a,b: a+b,x)
)

# %%
dataframe.tail(10)
# Out:
#                  datetime             city state country     shape  \
# 88669 2013-09-09 21:00:00  milton (canada)    on      ca  fireball
# 88670 2013-09-09 21:00:00        woodstock    ga      us    sphere
# 88671 2013-09-09 21:15:00        nashville    tn      us     light
# 88672 2013-09-09 22:00:00            boise    id      us    circle
# 88673 2013-09-09 22:00:00        kalispell    mt      us      disk
# 88674 2013-09-09 22:00:00             napa    ca      us     other
# 88675 2013-09-09 22:20:00           vienna    va      us    circle
# 88676 2013-09-09 23:00:00           edmond    ok      us     cigar
# 88677 2013-09-09 23:00:00            starr    sc      us   diamond
# 88678 2013-09-09 23:30:00   ft. lauderdale    fl      us      oval
#
#       duration (seconds) duration (hours/min)  \
# 88669              180.0            3 minutes
# 88670               20.0           20 seconds
# 88671              600.0           10 minutes
# 88672             1200.0           20 minutes
# 88673                0.0           continuing
# 88674             1200.0                 hour
# 88675                5.0            5 seconds
# 88676             1020.0           17 minutes
# 88677                0.0             2 nights
# 88678                0.0       still occuring
#
#                                                 comments date posted  \
# 88669              Massive Bright Orange Fireball in Sky  2013-09-30
# 88670  Driving 575 at 21:00 hrs saw a white and green...  2013-09-30
# 88671  Round from the distance/slowly changing colors...  2013-09-30
# 88672  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...  2013-09-30
# 88673  I was letting my dogs our for the night when I...  2013-09-30
# 88674                                       Napa UFO&#44  2013-09-30
# 88675  Saw a five gold lit cicular craft moving fastl...  2013-09-30
# 88676  2 witnesses 2  miles apart&#44 Red &amp; White...  2013-09-30
# 88677  On September ninth my wife and i noticed stran...  2013-09-30
# 88678  Hovering object lit with red and white lights&...  2013-09-30
#
#          latitude   longitude                         lat_splited  \
# 88669        46.3  -63.216667                    [, 4, 6, ., 3, ]
# 88670  34.1013889  -84.519444  [, 3, 4, ., 1, 0, 1, 3, 8, 8, 9, ]
# 88671  36.1658333  -86.784444  [, 3, 6, ., 1, 6, 5, 8, 3, 3, 3, ]
# 88672  43.6136111 -116.202500  [, 4, 3, ., 6, 1, 3, 6, 1, 1, 1, ]
# 88673  48.1958333 -114.311944  [, 4, 8, ., 1, 9, 5, 8, 3, 3, 3, ]
# 88674  38.2972222 -122.284444  [, 3, 8, ., 2, 9, 7, 2, 2, 2, 2, ]
# 88675  38.9011111  -77.265556  [, 3, 8, ., 9, 0, 1, 1, 1, 1, 1, ]
# 88676  35.6527778  -97.477778  [, 3, 5, ., 6, 5, 2, 7, 7, 7, 8, ]
# 88677  34.3769444  -82.695833  [, 3, 4, ., 3, 7, 6, 9, 4, 4, 4, ]
# 88678  26.1219444  -80.143611  [, 2, 6, ., 1, 2, 1, 9, 4, 4, 4, ]
#
#                          lat_filtered   lat_final
# 88669                    [4, 6, ., 3]        46.3
# 88670  [3, 4, ., 1, 0, 1, 3, 8, 8, 9]  34.1013889
# 88671  [3, 6, ., 1, 6, 5, 8, 3, 3, 3]  36.1658333
# 88672  [4, 3, ., 6, 1, 3, 6, 1, 1, 1]  43.6136111
# 88673  [4, 8, ., 1, 9, 5, 8, 3, 3, 3]  48.1958333
# 88674  [3, 8, ., 2, 9, 7, 2, 2, 2, 2]  38.2972222
# 88675  [3, 8, ., 9, 0, 1, 1, 1, 1, 1]  38.9011111
# 88676  [3, 5, ., 6, 5, 2, 7, 7, 7, 8]  35.6527778
# 88677  [3, 4, ., 3, 7, 6, 9, 4, 4, 4]  34.3769444
# 88678  [2, 6, ., 1, 2, 1, 9, 4, 4, 4]  26.1219444

# %%
dataframe['lat_final'] = dataframe['lat_final'].astype('float')

# %%
dataframe.dtypes
# Out:
# datetime                datetime64[ns]
# city                            object
# state                           object
# country                         object
# shape                           object
# duration (seconds)              object
# duration (hours/min)            object
# comments                        object
# date posted             datetime64[ns]
# latitude                        object
# longitude                      float64
# lat_splited                     object
# lat_filtered                    object
# lat_final                      float64
# dtype: object

# %%
dataframe['latitude'] = dataframe['lat_final']

# %%
dataframe.dtypes
# Out:
# datetime                datetime64[ns]
# city                            object
# state                           object
# country                         object
# shape                           object
# duration (seconds)              object
# duration (hours/min)            object
# comments                        object
# date posted             datetime64[ns]
# latitude                       float64
# longitude                      float64
# lat_splited                     object
# lat_filtered                    object
# lat_final                      float64
# dtype: object

# %%
dataframe.tail(10)
# Out:
#                  datetime             city state country     shape  \
# 88669 2013-09-09 21:00:00  milton (canada)    on      ca  fireball
# 88670 2013-09-09 21:00:00        woodstock    ga      us    sphere
# 88671 2013-09-09 21:15:00        nashville    tn      us     light
# 88672 2013-09-09 22:00:00            boise    id      us    circle
# 88673 2013-09-09 22:00:00        kalispell    mt      us      disk
# 88674 2013-09-09 22:00:00             napa    ca      us     other
# 88675 2013-09-09 22:20:00           vienna    va      us    circle
# 88676 2013-09-09 23:00:00           edmond    ok      us     cigar
# 88677 2013-09-09 23:00:00            starr    sc      us   diamond
# 88678 2013-09-09 23:30:00   ft. lauderdale    fl      us      oval
#
#       duration (seconds) duration (hours/min)  \
# 88669              180.0            3 minutes
# 88670               20.0           20 seconds
# 88671              600.0           10 minutes
# 88672             1200.0           20 minutes
# 88673                0.0           continuing
# 88674             1200.0                 hour
# 88675                5.0            5 seconds
# 88676             1020.0           17 minutes
# 88677                0.0             2 nights
# 88678                0.0       still occuring
#
#                                                 comments date posted  \
# 88669              Massive Bright Orange Fireball in Sky  2013-09-30
# 88670  Driving 575 at 21:00 hrs saw a white and green...  2013-09-30
# 88671  Round from the distance/slowly changing colors...  2013-09-30
# 88672  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...  2013-09-30
# 88673  I was letting my dogs our for the night when I...  2013-09-30
# 88674                                       Napa UFO&#44  2013-09-30
# 88675  Saw a five gold lit cicular craft moving fastl...  2013-09-30
# 88676  2 witnesses 2  miles apart&#44 Red &amp; White...  2013-09-30
# 88677  On September ninth my wife and i noticed stran...  2013-09-30
# 88678  Hovering object lit with red and white lights&...  2013-09-30
#
#         latitude   longitude                         lat_splited  \
# 88669  46.300000  -63.216667                    [, 4, 6, ., 3, ]
# 88670  34.101389  -84.519444  [, 3, 4, ., 1, 0, 1, 3, 8, 8, 9, ]
# 88671  36.165833  -86.784444  [, 3, 6, ., 1, 6, 5, 8, 3, 3, 3, ]
# 88672  43.613611 -116.202500  [, 4, 3, ., 6, 1, 3, 6, 1, 1, 1, ]
# 88673  48.195833 -114.311944  [, 4, 8, ., 1, 9, 5, 8, 3, 3, 3, ]
# 88674  38.297222 -122.284444  [, 3, 8, ., 2, 9, 7, 2, 2, 2, 2, ]
# 88675  38.901111  -77.265556  [, 3, 8, ., 9, 0, 1, 1, 1, 1, 1, ]
# 88676  35.652778  -97.477778  [, 3, 5, ., 6, 5, 2, 7, 7, 7, 8, ]
# 88677  34.376944  -82.695833  [, 3, 4, ., 3, 7, 6, 9, 4, 4, 4, ]
# 88678  26.121944  -80.143611  [, 2, 6, ., 1, 2, 1, 9, 4, 4, 4, ]
#
#                          lat_filtered  lat_final
# 88669                    [4, 6, ., 3]  46.300000
# 88670  [3, 4, ., 1, 0, 1, 3, 8, 8, 9]  34.101389
# 88671  [3, 6, ., 1, 6, 5, 8, 3, 3, 3]  36.165833
# 88672  [4, 3, ., 6, 1, 3, 6, 1, 1, 1]  43.613611
# 88673  [4, 8, ., 1, 9, 5, 8, 3, 3, 3]  48.195833
# 88674  [3, 8, ., 2, 9, 7, 2, 2, 2, 2]  38.297222
# 88675  [3, 8, ., 9, 0, 1, 1, 1, 1, 1]  38.901111
# 88676  [3, 5, ., 6, 5, 2, 7, 7, 7, 8]  35.652778
# 88677  [3, 4, ., 3, 7, 6, 9, 4, 4, 4]  34.376944
# 88678  [2, 6, ., 1, 2, 1, 9, 4, 4, 4]  26.121944

# %%
dataframe['duration (seconds)'] = dataframe['duration (seconds)'].astype('str')
dataframe['duration (seconds)'] = dataframe['duration (seconds)'].str.strip()
dataframe['dur_splited'] = dataframe['duration (seconds)'].str.split('')

# %%
dataframe['dur_filtered'] = dataframe['dur_splited'].apply(
    lambda x: list(filter(
        lambda a:  regex_match(a),x
    ))
)

# %%
dataframe.tail(10)
# Out:
#                  datetime             city state country     shape  \
# 88669 2013-09-09 21:00:00  milton (canada)    on      ca  fireball
# 88670 2013-09-09 21:00:00        woodstock    ga      us    sphere
# 88671 2013-09-09 21:15:00        nashville    tn      us     light
# 88672 2013-09-09 22:00:00            boise    id      us    circle
# 88673 2013-09-09 22:00:00        kalispell    mt      us      disk
# 88674 2013-09-09 22:00:00             napa    ca      us     other
# 88675 2013-09-09 22:20:00           vienna    va      us    circle
# 88676 2013-09-09 23:00:00           edmond    ok      us     cigar
# 88677 2013-09-09 23:00:00            starr    sc      us   diamond
# 88678 2013-09-09 23:30:00   ft. lauderdale    fl      us      oval
#
#       duration (seconds) duration (hours/min)  \
# 88669              180.0            3 minutes
# 88670               20.0           20 seconds
# 88671              600.0           10 minutes
# 88672             1200.0           20 minutes
# 88673                0.0           continuing
# 88674             1200.0                 hour
# 88675                5.0            5 seconds
# 88676             1020.0           17 minutes
# 88677                0.0             2 nights
# 88678                0.0       still occuring
#
#                                                 comments date posted  \
# 88669              Massive Bright Orange Fireball in Sky  2013-09-30
# 88670  Driving 575 at 21:00 hrs saw a white and green...  2013-09-30
# 88671  Round from the distance/slowly changing colors...  2013-09-30
# 88672  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...  2013-09-30
# 88673  I was letting my dogs our for the night when I...  2013-09-30
# 88674                                       Napa UFO&#44  2013-09-30
# 88675  Saw a five gold lit cicular craft moving fastl...  2013-09-30
# 88676  2 witnesses 2  miles apart&#44 Red &amp; White...  2013-09-30
# 88677  On September ninth my wife and i noticed stran...  2013-09-30
# 88678  Hovering object lit with red and white lights&...  2013-09-30
#
#         latitude   longitude                         lat_splited  \
# 88669  46.300000  -63.216667                    [, 4, 6, ., 3, ]
# 88670  34.101389  -84.519444  [, 3, 4, ., 1, 0, 1, 3, 8, 8, 9, ]
# 88671  36.165833  -86.784444  [, 3, 6, ., 1, 6, 5, 8, 3, 3, 3, ]
# 88672  43.613611 -116.202500  [, 4, 3, ., 6, 1, 3, 6, 1, 1, 1, ]
# 88673  48.195833 -114.311944  [, 4, 8, ., 1, 9, 5, 8, 3, 3, 3, ]
# 88674  38.297222 -122.284444  [, 3, 8, ., 2, 9, 7, 2, 2, 2, 2, ]
# 88675  38.901111  -77.265556  [, 3, 8, ., 9, 0, 1, 1, 1, 1, 1, ]
# 88676  35.652778  -97.477778  [, 3, 5, ., 6, 5, 2, 7, 7, 7, 8, ]
# 88677  34.376944  -82.695833  [, 3, 4, ., 3, 7, 6, 9, 4, 4, 4, ]
# 88678  26.121944  -80.143611  [, 2, 6, ., 1, 2, 1, 9, 4, 4, 4, ]
#
#                          lat_filtered  lat_final             dur_splited  \
# 88669                    [4, 6, ., 3]  46.300000     [, 1, 8, 0, ., 0, ]
# 88670  [3, 4, ., 1, 0, 1, 3, 8, 8, 9]  34.101389        [, 2, 0, ., 0, ]
# 88671  [3, 6, ., 1, 6, 5, 8, 3, 3, 3]  36.165833     [, 6, 0, 0, ., 0, ]
# 88672  [4, 3, ., 6, 1, 3, 6, 1, 1, 1]  43.613611  [, 1, 2, 0, 0, ., 0, ]
# 88673  [4, 8, ., 1, 9, 5, 8, 3, 3, 3]  48.195833           [, 0, ., 0, ]
# 88674  [3, 8, ., 2, 9, 7, 2, 2, 2, 2]  38.297222  [, 1, 2, 0, 0, ., 0, ]
# 88675  [3, 8, ., 9, 0, 1, 1, 1, 1, 1]  38.901111           [, 5, ., 0, ]
# 88676  [3, 5, ., 6, 5, 2, 7, 7, 7, 8]  35.652778  [, 1, 0, 2, 0, ., 0, ]
# 88677  [3, 4, ., 3, 7, 6, 9, 4, 4, 4]  34.376944           [, 0, ., 0, ]
# 88678  [2, 6, ., 1, 2, 1, 9, 4, 4, 4]  26.121944           [, 0, ., 0, ]
#
#              dur_filtered
# 88669     [1, 8, 0, ., 0]
# 88670        [2, 0, ., 0]
# 88671     [6, 0, 0, ., 0]
# 88672  [1, 2, 0, 0, ., 0]
# 88673           [0, ., 0]
# 88674  [1, 2, 0, 0, ., 0]
# 88675           [5, ., 0]
# 88676  [1, 0, 2, 0, ., 0]
# 88677           [0, ., 0]
# 88678           [0, ., 0]

# %%
def check_if_array_empty(a):
    if len(a) > 0:
        return a
    else:
        return ['0','.','0']

dataframe['dur_filtered'] = dataframe['dur_filtered'].apply(lambda x: check_if_array_empty(x))

# %%
dataframe['dur_final'] = dataframe['dur_filtered'].apply(
    lambda x: fc.reduce(
        lambda a,b: a+b,x)
)

# %%
dataframe['duration (seconds)'] = dataframe['dur_final']
dataframe['duration (seconds)'] = dataframe['duration (seconds)'].astype('float')

# %%
dataframe = dataframe.drop(columns = ['lat_splited','lat_filtered','lat_final','dur_splited','dur_filtered','dur_final'])

# %%
dataframe.dtypes
# Out:
# datetime                datetime64[ns]
# city                            object
# state                           object
# country                         object
# shape                           object
# duration (seconds)             float64
# duration (hours/min)            object
# comments                        object
# date posted             datetime64[ns]
# latitude                       float64
# longitude                      float64
# dtype: object

# %%
size = dataframe.groupby(['state']).size().sort_values()
print(size)
# Out:
# state
# vi        1
# yk        7
# yt       14
# nt       23
# pe       23
#       ...
# ny     3506
# tx     4041
# fl     4596
# wa     4650
# ca    10449
# Length: 68, dtype: int64

# %%
dataframe['state_check'] = dataframe['state'].isnull()
dataframe['country_check'] = dataframe['country'].isnull()

# %%
dataframe.groupby(['state_check']).size()
# Out:
# state_check
# False    81270
# True      7409
# dtype: int64

# %%
dataframe.groupby(['country_check']).size()
# Out:
# country_check
# False    76314
# True     12365
# dtype: int64

# %%
t_df = dataframe.copy()
t_df = t_df[t_df['country_check'] == True]
t_df.head(20)
# Out:
#                datetime                                         city state  \
# 1   1949-10-10 21:00:00                                 lackland afb    tx
# 18  1973-10-10 23:00:00                                  bermuda nas   NaN
# 19  1974-10-10 17:00:00                                 willow beach    az
# 30  1979-10-10 22:00:00                         saddle lake (canada)    ab
# 36  1982-10-10 07:00:00                       gisborne (new zealand)   NaN
# 41  1986-10-10 20:00:00                               holmes/pawling    ny
# 42  1987-10-10 20:00:00                      manilla (rr#1) (canada)    on
# 49  1989-10-10 21:00:00                                     kranklin    ky
# 50  1990-10-10 20:00:00                               pense (canada)    sa
# 58  1993-10-10 03:00:00                            zlatoust (russia)   NaN
# 61  1994-10-10 15:00:00                                    mercedies    tx
# 65  1995-10-10 17:05:00                    puerto rico (puerto rico)    pr
# 69  1996-10-10 20:00:00           lake macquarie (nsw&#44 australia)   NaN
# 76  1998-10-10 02:00:00                                turin (italy)   NaN
# 82  1998-10-10 20:30:00                         nyc/westchester area    ny
# 88  1999-10-10 03:00:00                 st. agnes de dundee (canada)    pq
# 97  1999-10-10 22:00:00                          dorset (uk/england)   NaN
# 98  1999-10-10 22:30:00                     casey key (north end of)    fl
# 102 2000-10-10 03:45:00  carnival cruise ship (paradise) (caribbean)   NaN
# 105 2000-10-10 16:00:00                                       jueanu    wi
#
#     country     shape  duration (seconds) duration (hours/min)  \
# 1       NaN     light              7200.0              1-2 hrs
# 18      NaN     light                20.0              20 sec.
# 19      NaN     light               120.0                2 min
# 30      NaN  triangle               270.0     4.5 or more min.
# 36      NaN      disk               120.0                 2min
# 41      NaN   chevron               180.0            3 minutes
# 42      NaN      disk               600.0              10/mins
# 49      NaN  triangle               180.0                 3min
# 50      NaN   unknown               180.0              1/2 hr.
# 58      NaN    sphere              1200.0           20 minutes
# 61      NaN     cigar              3600.0               1 hour
# 65      NaN       NaN                 0.0                  NaN
# 69      NaN     light               300.0                5 min
# 76      NaN      disk                15.0               15 sec
# 82      NaN  triangle                60.0              < 1 min
# 88      NaN       egg              5400.0              90 min.
# 97      NaN     flash                 1.0            <1 second
# 98      NaN  triangle               120.0      several minutes
# 102     NaN     flash              1200.0             20 mins.
# 105     NaN  triangle                45.0           45 seconds
#
#                                               comments date posted   latitude  \
# 1    1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 18   saw fast moving blip on the radar scope thin w...  2002-01-11  32.364167
# 19   The object was a brillant white light standing...  2001-02-18   0.000000
# 30   Lights far above&#44  that glance; then flee f...  2005-01-19  53.970571
# 36         gisborne nz 1982 wainui beach to sponge bay  2002-01-11  38.662334
# 41   Football Field Sized Chevron with bright white...  2007-10-08  41.523427
# 42   We could clearly see the craft and observed in...  2001-08-05   0.000000
# 49         Triangle seen in franklin Ky - october 1989  2005-05-11  36.722263
# 50   i saw something one rainy night&#44 and i&#39l...  2001-10-12   0.000000
# 58   I woke up at night and looked out the window n...  2004-12-14  55.183333
# 61   ufo chased by fighter jet over Rio Grande Vall...  2011-12-12  26.149798
# 65   Woman calls regarding fiance who is having pec...  1999-11-02  18.220833
# 69   RED LIGHT WITH OTHER RED FLASHING LIGHT&#44 ON...  1999-05-24  33.093373
# 76   We were doing a patrol during the night&#44me ...  2005-01-19   0.000000
# 82                                     Lights over NYC  2006-10-30  40.935998
# 88   early morning bright object egg shape fully co...  2000-12-02   0.000000
# 97   Whilst out late night cycling (as i have done ...  2006-02-14   0.000000
# 98   A large trianglual shaped craft flew from hori...  2002-09-19  27.150053
# 102                  Motionless eratic flashing light.  2000-12-09   0.000000
# 105                             5 bight light V shaped  2000-12-02  43.405550
#
#       longitude  state_check  country_check
# 1    -98.581082        False           True
# 18   -64.678611         True           True
# 19     0.000000        False           True
# 30  -111.689885        False           True
# 36   178.017649         True           True
# 41   -73.646795        False           True
# 42     0.000000        False           True
# 49   -86.577218        False           True
# 50     0.000000        False           True
# 58    59.650000         True           True
# 61   -97.913611        False           True
# 65   -66.590149        False           True
# 69   151.588982         True           True
# 76     0.000000         True           True
# 82   -73.901708        False           True
# 88     0.000000        False           True
# 97     0.000000         True           True
# 98   -82.480653        False           True
# 102    0.000000         True           True
# 105  -88.705104        False           True

# %%
t_df['city'] = t_df['city'].astype('str')
t_df['city'] = t_df['city'].str.strip()
t_df.head(5)
# Out:
#               datetime                    city state country     shape  \
# 1  1949-10-10 21:00:00            lackland afb    tx     NaN     light
# 18 1973-10-10 23:00:00             bermuda nas   NaN     NaN     light
# 19 1974-10-10 17:00:00            willow beach    az     NaN     light
# 30 1979-10-10 22:00:00    saddle lake (canada)    ab     NaN  triangle
# 36 1982-10-10 07:00:00  gisborne (new zealand)   NaN     NaN      disk
#
#     duration (seconds) duration (hours/min)  \
# 1               7200.0              1-2 hrs
# 18                20.0              20 sec.
# 19               120.0                2 min
# 30               270.0     4.5 or more min.
# 36               120.0                 2min
#
#                                              comments date posted   latitude  \
# 1   1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 18  saw fast moving blip on the radar scope thin w...  2002-01-11  32.364167
# 19  The object was a brillant white light standing...  2001-02-18   0.000000
# 30  Lights far above&#44  that glance; then flee f...  2005-01-19  53.970571
# 36        gisborne nz 1982 wainui beach to sponge bay  2002-01-11  38.662334
#
#      longitude  state_check  country_check
# 1   -98.581082        False           True
# 18  -64.678611         True           True
# 19    0.000000        False           True
# 30 -111.689885        False           True
# 36  178.017649         True           True

# %%
def country_check(a,string,value):
    if string in a:
        return value
    else:
        return a

# %%
t_df['city_new'] = t_df['city'].str.split('(')
t_df['filtr'] = t_df['city_new'].apply(lambda a: len(a) > 1)
t_df = t_df[t_df['filtr'] == True ]
t_df['filled_country'] = t_df['city_new'].apply(lambda a: a[max(len(a)-1,0)])
t_df['filled_country'] = t_df['filled_country'].astype('str')
t_df['filled_country'] = t_df['filled_country'].str.rstrip(')')
t_df['filled_country'] = t_df['filled_country'].str.lower()
t_df['filled_country'] = t_df['filled_country'].apply(lambda a: country_check(a,'uk/','united kingdom'))
t_df['filled_country'] = t_df['filled_country'].apply(lambda a: country_check(a,'australia','australia') )
t_df.head(5)
# Out:
#               datetime                     city state country     shape  \
# 30 1979-10-10 22:00:00     saddle lake (canada)    ab     NaN  triangle
# 36 1982-10-10 07:00:00   gisborne (new zealand)   NaN     NaN      disk
# 42 1987-10-10 20:00:00  manilla (rr#1) (canada)    on     NaN      disk
# 50 1990-10-10 20:00:00           pense (canada)    sa     NaN   unknown
# 58 1993-10-10 03:00:00        zlatoust (russia)   NaN     NaN    sphere
#
#     duration (seconds) duration (hours/min)  \
# 30               270.0     4.5 or more min.
# 36               120.0                 2min
# 42               600.0              10/mins
# 50               180.0              1/2 hr.
# 58              1200.0           20 minutes
#
#                                              comments date posted   latitude  \
# 30  Lights far above&#44  that glance; then flee f...  2005-01-19  53.970571
# 36        gisborne nz 1982 wainui beach to sponge bay  2002-01-11  38.662334
# 42  We could clearly see the craft and observed in...  2001-08-05   0.000000
# 50  i saw something one rainy night&#44 and i&#39l...  2001-10-12   0.000000
# 58  I woke up at night and looked out the window n...  2004-12-14  55.183333
#
#      longitude  state_check  country_check                     city_new  \
# 30 -111.689885        False           True      [saddle lake , canada)]
# 36  178.017649         True           True    [gisborne , new zealand)]
# 42    0.000000        False           True  [manilla , rr#1) , canada)]
# 50    0.000000        False           True            [pense , canada)]
# 58   59.650000         True           True         [zlatoust , russia)]
#
#     filtr filled_country
# 30   True         canada
# 36   True    new zealand
# 42   True         canada
# 50   True         canada
# 58   True         russia

# %%
countries['name'] = countries['name'].astype('str')
countries['name'] = countries['name'].str.lower()
countries['code'] = countries['code'].str.lower()
countries['filled_country'] = countries['name']

countries.head(5)
# Out:
#        id code                  name continent        filled_country
# 0  302672   ad               andorra        EU               andorra
# 1  302618   ae  united arab emirates        AS  united arab emirates
# 2  302619   af           afghanistan        AS           afghanistan
# 3  302722   ag   antigua and barbuda       NaN   antigua and barbuda
# 4  302723   ai              anguilla       NaN              anguilla

# %%
result = pd.merge(t_df,countries,on='filled_country',how='left')
result.head(20)
# Out:
#               datetime                                         city state  \
# 0  1979-10-10 22:00:00                         saddle lake (canada)    ab
# 1  1982-10-10 07:00:00                       gisborne (new zealand)   NaN
# 2  1987-10-10 20:00:00                      manilla (rr#1) (canada)    on
# 3  1990-10-10 20:00:00                               pense (canada)    sa
# 4  1993-10-10 03:00:00                            zlatoust (russia)   NaN
# 5  1995-10-10 17:05:00                    puerto rico (puerto rico)    pr
# 6  1996-10-10 20:00:00           lake macquarie (nsw&#44 australia)   NaN
# 7  1998-10-10 02:00:00                                turin (italy)   NaN
# 8  1999-10-10 03:00:00                 st. agnes de dundee (canada)    pq
# 9  1999-10-10 22:00:00                          dorset (uk/england)   NaN
# 10 1999-10-10 22:30:00                     casey key (north end of)    fl
# 11 2000-10-10 03:45:00  carnival cruise ship (paradise) (caribbean)   NaN
# 12 2003-10-10 23:00:00       bickerton (near wetherby) (uk/england)   NaN
# 13 2004-10-10 15:20:00                        kedainiai (lithuania)   NaN
# 14 2007-10-10 23:20:00                               stord (norway)   NaN
# 15 2012-10-10 20:17:00                        mount albert (canada)    on
# 16 1989-10-11 02:30:00                         copenhagen (denmark)   NaN
# 17 1997-10-11 22:00:00                      hafnarfjordur (iceland)   NaN
# 18 1997-10-11 23:30:00                esl&ouml;&#44 scania (sweden)   NaN
# 19 2003-10-11 13:00:00  nebraska (above?&#44 or above south dakota)    ne
#
#    country     shape  duration (seconds) duration (hours/min)  \
# 0      NaN  triangle               270.0     4.5 or more min.
# 1      NaN      disk               120.0                 2min
# 2      NaN      disk               600.0              10/mins
# 3      NaN   unknown               180.0              1/2 hr.
# 4      NaN    sphere              1200.0           20 minutes
# 5      NaN       NaN                 0.0                  NaN
# 6      NaN     light               300.0                5 min
# 7      NaN      disk                15.0               15 sec
# 8      NaN       egg              5400.0              90 min.
# 9      NaN     flash                 1.0            <1 second
# 10     NaN  triangle               120.0      several minutes
# 11     NaN     flash              1200.0             20 mins.
# 12     NaN   unknown              2700.0            45minutes
# 13     NaN      oval               240.0                 4min
# 14     NaN     light               600.0               10 min
# 15     NaN  triangle                30.0           30 seconds
# 16     NaN  fireball               180.0         3min.max&#39
# 17     NaN    sphere               300.0                5 min
# 18     NaN       NaN               600.0           10 minutes
# 19     NaN     cigar                 2.0              seconds
#
#                                              comments date posted   latitude  \
# 0   Lights far above&#44  that glance; then flee f...  2005-01-19  53.970571
# 1         gisborne nz 1982 wainui beach to sponge bay  2002-01-11  38.662334
# 2   We could clearly see the craft and observed in...  2001-08-05   0.000000
# 3   i saw something one rainy night&#44 and i&#39l...  2001-10-12   0.000000
# 4   I woke up at night and looked out the window n...  2004-12-14  55.183333
# 5   Woman calls regarding fiance who is having pec...  1999-11-02  18.220833
# 6   RED LIGHT WITH OTHER RED FLASHING LIGHT&#44 ON...  1999-05-24  33.093373
# 7   We were doing a patrol during the night&#44me ...  2005-01-19   0.000000
# 8   early morning bright object egg shape fully co...  2000-12-02   0.000000
# 9   Whilst out late night cycling (as i have done ...  2006-02-14   0.000000
# 10  A large trianglual shaped craft flew from hori...  2002-09-19  27.150053
# 11                  Motionless eratic flashing light.  2000-12-09   0.000000
# 12  two bright&#44 but fuzzy lights going in a hov...  2003-10-15  53.070884
# 13  6 oval light objects very quickly rounded unde...  2004-10-27  55.288131
# 14  Thise could be an ETV case&#44 but it could al...  2008-01-21  59.900209
# 15  On Wednesday October 10 2012 at 8:17 pm in Mou...  2012-10-30  44.136076
# 16  ann:Light as an exploding thing then taking fo...  2004-02-12   0.000000
# 17                                 playing with a jet  2008-06-12  64.066667
# 18  During an IYCW (International Youth Camp Weeke...  1999-01-28   0.000000
# 19  rather large cigar shaped object photographed ...  2003-10-15  41.492537
#
#      longitude  state_check  country_check  \
# 0  -111.689885        False           True
# 1   178.017649         True           True
# 2     0.000000        False           True
# 3     0.000000        False           True
# 4    59.650000         True           True
# 5   -66.590149        False           True
# 6   151.588982         True           True
# 7     0.000000         True           True
# 8     0.000000        False           True
# 9     0.000000         True           True
# 10  -82.480653        False           True
# 11    0.000000         True           True
# 12   -2.736506         True           True
# 13   23.957728         True           True
# 14    5.282347         True           True
# 15  -79.308339        False           True
# 16    0.000000         True           True
# 17  -21.950000         True           True
# 18    0.000000         True           True
# 19  -99.901813        False           True
#
#                                            city_new  filtr  \
# 0                           [saddle lake , canada)]   True
# 1                         [gisborne , new zealand)]   True
# 2                       [manilla , rr#1) , canada)]   True
# 3                                 [pense , canada)]   True
# 4                              [zlatoust , russia)]   True
# 5                      [puerto rico , puerto rico)]   True
# 6             [lake macquarie , nsw&#44 australia)]   True
# 7                                  [turin , italy)]   True
# 8                   [st. agnes de dundee , canada)]   True
# 9                            [dorset , uk/england)]   True
# 10                      [casey key , north end of)]   True
# 11  [carnival cruise ship , paradise) , caribbean)]   True
# 12       [bickerton , near wetherby) , uk/england)]   True
# 13                         [kedainiai , lithuania)]   True
# 14                                [stord , norway)]   True
# 15                         [mount albert , canada)]   True
# 16                          [copenhagen , denmark)]   True
# 17                       [hafnarfjordur , iceland)]   True
# 18                 [esl&ouml;&#44 scania , sweden)]   True
# 19   [nebraska , above?&#44 or above south dakota)]   True
#
#                       filled_country        id code            name continent
# 0                             canada  302730.0   ca          canada       NaN
# 1                        new zealand  302776.0   nz     new zealand        OC
# 2                             canada  302730.0   ca          canada       NaN
# 3                             canada  302730.0   ca          canada       NaN
# 4                             russia  302714.0   ru          russia        EU
# 5                        puerto rico  302751.0   pr     puerto rico       NaN
# 6                          australia  302764.0   au       australia        OC
# 7                              italy  302697.0   it           italy        EU
# 8                             canada  302730.0   ca          canada       NaN
# 9                     united kingdom  302688.0   gb  united kingdom        EU
# 10                      north end of       NaN  NaN             NaN       NaN
# 11                         caribbean       NaN  NaN             NaN       NaN
# 12                    united kingdom  302688.0   gb  united kingdom        EU
# 13                         lithuania  302700.0   lt       lithuania        EU
# 14                            norway  302709.0   no          norway        EU
# 15                            canada  302730.0   ca          canada       NaN
# 16                           denmark  302682.0   dk         denmark        EU
# 17                           iceland  302696.0   is         iceland        EU
# 18                            sweden  302715.0   se          sweden        EU
# 19  above?&#44 or above south dakota       NaN  NaN             NaN       NaN

# %%
result['check'] = result['name'].isnull()
result.groupby(['check']).size().sort_values()
# Out:
# check
# True     1544
# False    4276
# dtype: int64

# %%
result['country'] = result['code']
result.head(10)
# Out:
#              datetime                                city state country  \
# 0 1979-10-10 22:00:00                saddle lake (canada)    ab      ca
# 1 1982-10-10 07:00:00              gisborne (new zealand)   NaN      nz
# 2 1987-10-10 20:00:00             manilla (rr#1) (canada)    on      ca
# 3 1990-10-10 20:00:00                      pense (canada)    sa      ca
# 4 1993-10-10 03:00:00                   zlatoust (russia)   NaN      ru
# 5 1995-10-10 17:05:00           puerto rico (puerto rico)    pr      pr
# 6 1996-10-10 20:00:00  lake macquarie (nsw&#44 australia)   NaN      au
# 7 1998-10-10 02:00:00                       turin (italy)   NaN      it
# 8 1999-10-10 03:00:00        st. agnes de dundee (canada)    pq      ca
# 9 1999-10-10 22:00:00                 dorset (uk/england)   NaN      gb
#
#       shape  duration (seconds) duration (hours/min)  \
# 0  triangle               270.0     4.5 or more min.
# 1      disk               120.0                 2min
# 2      disk               600.0              10/mins
# 3   unknown               180.0              1/2 hr.
# 4    sphere              1200.0           20 minutes
# 5       NaN                 0.0                  NaN
# 6     light               300.0                5 min
# 7      disk                15.0               15 sec
# 8       egg              5400.0              90 min.
# 9     flash                 1.0            <1 second
#
#                                             comments date posted   latitude  \
# 0  Lights far above&#44  that glance; then flee f...  2005-01-19  53.970571
# 1        gisborne nz 1982 wainui beach to sponge bay  2002-01-11  38.662334
# 2  We could clearly see the craft and observed in...  2001-08-05   0.000000
# 3  i saw something one rainy night&#44 and i&#39l...  2001-10-12   0.000000
# 4  I woke up at night and looked out the window n...  2004-12-14  55.183333
# 5  Woman calls regarding fiance who is having pec...  1999-11-02  18.220833
# 6  RED LIGHT WITH OTHER RED FLASHING LIGHT&#44 ON...  1999-05-24  33.093373
# 7  We were doing a patrol during the night&#44me ...  2005-01-19   0.000000
# 8  early morning bright object egg shape fully co...  2000-12-02   0.000000
# 9  Whilst out late night cycling (as i have done ...  2006-02-14   0.000000
#
#    ...  state_check  country_check                               city_new  \
# 0  ...        False           True                [saddle lake , canada)]
# 1  ...         True           True              [gisborne , new zealand)]
# 2  ...        False           True            [manilla , rr#1) , canada)]
# 3  ...        False           True                      [pense , canada)]
# 4  ...         True           True                   [zlatoust , russia)]
# 5  ...        False           True           [puerto rico , puerto rico)]
# 6  ...         True           True  [lake macquarie , nsw&#44 australia)]
# 7  ...         True           True                       [turin , italy)]
# 8  ...        False           True        [st. agnes de dundee , canada)]
# 9  ...         True           True                 [dorset , uk/england)]
#
#   filtr  filled_country        id  code            name continent  check
# 0  True          canada  302730.0    ca          canada       NaN  False
# 1  True     new zealand  302776.0    nz     new zealand        OC  False
# 2  True          canada  302730.0    ca          canada       NaN  False
# 3  True          canada  302730.0    ca          canada       NaN  False
# 4  True          russia  302714.0    ru          russia        EU  False
# 5  True     puerto rico  302751.0    pr     puerto rico       NaN  False
# 6  True       australia  302764.0    au       australia        OC  False
# 7  True           italy  302697.0    it           italy        EU  False
# 8  True          canada  302730.0    ca          canada       NaN  False
# 9  True  united kingdom  302688.0    gb  united kingdom        EU  False
#
# [10 rows x 21 columns]

# %%
result = result.drop(columns=['city_new','filtr','filled_country','id','code','name','continent','check'])
result.head(30)
# Out:
#               datetime                                         city state  \
# 0  1979-10-10 22:00:00                         saddle lake (canada)    ab
# 1  1982-10-10 07:00:00                       gisborne (new zealand)   NaN
# 2  1987-10-10 20:00:00                      manilla (rr#1) (canada)    on
# 3  1990-10-10 20:00:00                               pense (canada)    sa
# 4  1993-10-10 03:00:00                            zlatoust (russia)   NaN
# 5  1995-10-10 17:05:00                    puerto rico (puerto rico)    pr
# 6  1996-10-10 20:00:00           lake macquarie (nsw&#44 australia)   NaN
# 7  1998-10-10 02:00:00                                turin (italy)   NaN
# 8  1999-10-10 03:00:00                 st. agnes de dundee (canada)    pq
# 9  1999-10-10 22:00:00                          dorset (uk/england)   NaN
# 10 1999-10-10 22:30:00                     casey key (north end of)    fl
# 11 2000-10-10 03:45:00  carnival cruise ship (paradise) (caribbean)   NaN
# 12 2003-10-10 23:00:00       bickerton (near wetherby) (uk/england)   NaN
# 13 2004-10-10 15:20:00                        kedainiai (lithuania)   NaN
# 14 2007-10-10 23:20:00                               stord (norway)   NaN
# 15 2012-10-10 20:17:00                        mount albert (canada)    on
# 16 1989-10-11 02:30:00                         copenhagen (denmark)   NaN
# 17 1997-10-11 22:00:00                      hafnarfjordur (iceland)   NaN
# 18 1997-10-11 23:30:00                esl&ouml;&#44 scania (sweden)   NaN
# 19 2003-10-11 13:00:00  nebraska (above?&#44 or above south dakota)    ne
# 20 2004-10-11 10:00:00                        nuevo laredo (mexico)   NaN
# 21 2007-10-11 19:28:00                         brassall (australia)   NaN
# 22 2008-10-11 00:00:00                         klagenfurt (austria)   NaN
# 23 2008-10-11 17:30:00                         bellmere (australia)   NaN
# 24 2012-10-11 04:05:00         las vegas; enroute to (15 n freeway)    nv
# 25 1952-10-01 03:30:00                              fukuoka (japan)   NaN
# 26 1955-10-01 22:00:00                             mono lake (area)    ca
# 27 1967-10-01 19:00:00                    hudson&#39s hope (canada)    bc
# 28 1968-10-01 15:00:00                                  lima (peru)   NaN
# 29 1970-10-01 23:00:00                    indian ocean (usn vessel)   NaN
#
#    country     shape  duration (seconds) duration (hours/min)  \
# 0       ca  triangle               270.0     4.5 or more min.
# 1       nz      disk               120.0                 2min
# 2       ca      disk               600.0              10/mins
# 3       ca   unknown               180.0              1/2 hr.
# 4       ru    sphere              1200.0           20 minutes
# 5       pr       NaN                 0.0                  NaN
# 6       au     light               300.0                5 min
# 7       it      disk                15.0               15 sec
# 8       ca       egg              5400.0              90 min.
# 9       gb     flash                 1.0            <1 second
# 10     NaN  triangle               120.0      several minutes
# 11     NaN     flash              1200.0             20 mins.
# 12      gb   unknown              2700.0            45minutes
# 13      lt      oval               240.0                 4min
# 14      no     light               600.0               10 min
# 15      ca  triangle                30.0           30 seconds
# 16      dk  fireball               180.0         3min.max&#39
# 17      is    sphere               300.0                5 min
# 18      se       NaN               600.0           10 minutes
# 19     NaN     cigar                 2.0              seconds
# 20      mx     light              1200.0                20min
# 21      au   unknown              3600.0             1 hour +
# 22      at   chevron                60.0             1 minute
# 23      au  cylinder               240.0            4 minutes
# 24     NaN      disk                 0.0                  NaN
# 25      jp      disk              1200.0        about 20 mins
# 26     NaN    circle                 5.0      five seconds+/-
# 27      ca    sphere               120.0            2 minutes
# 28      pe    circle               300.0          2-5 minutes
# 29     NaN     light               240.0          3-4 minutes
#
#                                              comments date posted   latitude  \
# 0   Lights far above&#44  that glance; then flee f...  2005-01-19  53.970571
# 1         gisborne nz 1982 wainui beach to sponge bay  2002-01-11  38.662334
# 2   We could clearly see the craft and observed in...  2001-08-05   0.000000
# 3   i saw something one rainy night&#44 and i&#39l...  2001-10-12   0.000000
# 4   I woke up at night and looked out the window n...  2004-12-14  55.183333
# 5   Woman calls regarding fiance who is having pec...  1999-11-02  18.220833
# 6   RED LIGHT WITH OTHER RED FLASHING LIGHT&#44 ON...  1999-05-24  33.093373
# 7   We were doing a patrol during the night&#44me ...  2005-01-19   0.000000
# 8   early morning bright object egg shape fully co...  2000-12-02   0.000000
# 9   Whilst out late night cycling (as i have done ...  2006-02-14   0.000000
# 10  A large trianglual shaped craft flew from hori...  2002-09-19  27.150053
# 11                  Motionless eratic flashing light.  2000-12-09   0.000000
# 12  two bright&#44 but fuzzy lights going in a hov...  2003-10-15  53.070884
# 13  6 oval light objects very quickly rounded unde...  2004-10-27  55.288131
# 14  Thise could be an ETV case&#44 but it could al...  2008-01-21  59.900209
# 15  On Wednesday October 10 2012 at 8:17 pm in Mou...  2012-10-30  44.136076
# 16  ann:Light as an exploding thing then taking fo...  2004-02-12   0.000000
# 17                                 playing with a jet  2008-06-12  64.066667
# 18  During an IYCW (International Youth Camp Weeke...  1999-01-28   0.000000
# 19  rather large cigar shaped object photographed ...  2003-10-15  41.492537
# 20  While I was driving I stopped at a traffic lig...  2006-07-16  27.477936
# 21         Accidentally photographed very strange UFO  2007-11-28  27.597553
# 22  It came from the direction of the city&#44 whe...  2009-03-19  46.627940
# 23  Very large long white cylinder object travelin...  2009-01-10  27.088079
# 24                                UFO on 15 N freeway  2012-10-30  38.802610
# 25  UFO seen by multiple U. S. military personnel;...  2006-12-07  33.590355
# 26  NO KNOWN AIRCRAFT (1955 and maybe today) COULD...  2009-03-19  38.007059
# 27  Large round silver UFO in Peace River Valley 1...  2001-02-18  56.031639
# 28  It hovered over the park for several minutes t...  2005-07-13   0.000000
# 29  Bright object seemingly appeared out of nowher...  2004-07-08  33.137551
#
#      longitude  state_check  country_check
# 0  -111.689885        False           True
# 1   178.017649         True           True
# 2     0.000000        False           True
# 3     0.000000        False           True
# 4    59.650000         True           True
# 5   -66.590149        False           True
# 6   151.588982         True           True
# 7     0.000000         True           True
# 8     0.000000        False           True
# 9     0.000000         True           True
# 10  -82.480653        False           True
# 11    0.000000         True           True
# 12   -2.736506         True           True
# 13   23.957728         True           True
# 14    5.282347         True           True
# 15  -79.308339        False           True
# 16    0.000000         True           True
# 17  -21.950000         True           True
# 18    0.000000         True           True
# 19  -99.901813        False           True
# 20  -99.549573         True           True
# 21  152.745500         True           True
# 22   14.308990         True           True
# 23  152.928057         True           True
# 24 -116.419389        False           True
# 25  130.401716         True           True
# 26 -119.012259        False           True
# 27 -121.905722        False           True
# 28    0.000000         True           True
# 29   81.826172         True           True

# %%
result['country_check'] = result['country'].isnull()
result.groupby(['country_check']).size().sort_values()
# Out:
# country_check
# True     1547
# False    4273
# dtype: int64

# %%
result_2 = result.copy()

# %%
result_2 = result_2[result_2['country_check']== True]
result_2 = result_2[result_2['state_check']==False]
result_2['country'] = 'us'
result_2.head(5)
# Out:
#               datetime                                              city  \
# 10 1999-10-10 22:30:00                          casey key (north end of)
# 19 2003-10-11 13:00:00       nebraska (above?&#44 or above south dakota)
# 24 2012-10-11 04:05:00              las vegas; enroute to (15 n freeway)
# 26 1955-10-01 22:00:00                                  mono lake (area)
# 33 1985-10-01 21:30:00  santa margarita/atascadero (between&#44 hwy 101)
#
#    state country     shape  duration (seconds) duration (hours/min)  \
# 10    fl      us  triangle               120.0      several minutes
# 19    ne      us     cigar                 2.0              seconds
# 24    nv      us      disk                 0.0                  NaN
# 26    ca      us    circle                 5.0      five seconds+/-
# 33    ca      us     other               120.0       2 &#33/2  min.
#
#                                              comments date posted   latitude  \
# 10  A large trianglual shaped craft flew from hori...  2002-09-19  27.150053
# 19  rather large cigar shaped object photographed ...  2003-10-15  41.492537
# 24                                UFO on 15 N freeway  2012-10-30  38.802610
# 26  NO KNOWN AIRCRAFT (1955 and maybe today) COULD...  2009-03-19  38.007059
# 33  we were driving north on hwy 101 from san luis...  1999-06-23  35.423335
#
#      longitude  state_check  country_check
# 10  -82.480653        False           True
# 19  -99.901813        False           True
# 24 -116.419389        False           True
# 26 -119.012259        False           True
# 33 -120.618785        False           True

# %%
result = result[result['country_check'] == False]
result.head(5)
# Out:
#              datetime                     city state country     shape  \
# 0 1979-10-10 22:00:00     saddle lake (canada)    ab      ca  triangle
# 1 1982-10-10 07:00:00   gisborne (new zealand)   NaN      nz      disk
# 2 1987-10-10 20:00:00  manilla (rr#1) (canada)    on      ca      disk
# 3 1990-10-10 20:00:00           pense (canada)    sa      ca   unknown
# 4 1993-10-10 03:00:00        zlatoust (russia)   NaN      ru    sphere
#
#    duration (seconds) duration (hours/min)  \
# 0               270.0     4.5 or more min.
# 1               120.0                 2min
# 2               600.0              10/mins
# 3               180.0              1/2 hr.
# 4              1200.0           20 minutes
#
#                                             comments date posted   latitude  \
# 0  Lights far above&#44  that glance; then flee f...  2005-01-19  53.970571
# 1        gisborne nz 1982 wainui beach to sponge bay  2002-01-11  38.662334
# 2  We could clearly see the craft and observed in...  2001-08-05   0.000000
# 3  i saw something one rainy night&#44 and i&#39l...  2001-10-12   0.000000
# 4  I woke up at night and looked out the window n...  2004-12-14  55.183333
#
#     longitude  state_check  country_check
# 0 -111.689885        False          False
# 1  178.017649         True          False
# 2    0.000000        False          False
# 3    0.000000        False          False
# 4   59.650000         True          False

# %%
result.groupby(['country_check']).size().sort_values()
# Out:
# country_check
# False    4273
# dtype: int64

# %%
result_2.groupby(['country_check']).size().sort_values()
# Out:
# country_check
# True    1055
# dtype: int64

# %%
final = pd.concat([result,result_2])
final.head(5)
# Out:
#              datetime                     city state country     shape  \
# 0 1979-10-10 22:00:00     saddle lake (canada)    ab      ca  triangle
# 1 1982-10-10 07:00:00   gisborne (new zealand)   NaN      nz      disk
# 2 1987-10-10 20:00:00  manilla (rr#1) (canada)    on      ca      disk
# 3 1990-10-10 20:00:00           pense (canada)    sa      ca   unknown
# 4 1993-10-10 03:00:00        zlatoust (russia)   NaN      ru    sphere
#
#    duration (seconds) duration (hours/min)  \
# 0               270.0     4.5 or more min.
# 1               120.0                 2min
# 2               600.0              10/mins
# 3               180.0              1/2 hr.
# 4              1200.0           20 minutes
#
#                                             comments date posted   latitude  \
# 0  Lights far above&#44  that glance; then flee f...  2005-01-19  53.970571
# 1        gisborne nz 1982 wainui beach to sponge bay  2002-01-11  38.662334
# 2  We could clearly see the craft and observed in...  2001-08-05   0.000000
# 3  i saw something one rainy night&#44 and i&#39l...  2001-10-12   0.000000
# 4  I woke up at night and looked out the window n...  2004-12-14  55.183333
#
#     longitude  state_check  country_check
# 0 -111.689885        False          False
# 1  178.017649         True          False
# 2    0.000000        False          False
# 3    0.000000        False          False
# 4   59.650000         True          False

# %%
final.groupby(['country_check']).size().sort_values()
# Out:
# country_check
# True     1055
# False    4273
# dtype: int64

# %%
dataframe.head(5)
# Out:
#              datetime                  city state country     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3 1956-10-10 21:00:00                  edna    tx      us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi      us     light
#
#    duration (seconds) duration (hours/min)  \
# 0              2700.0           45 minutes
# 1              7200.0              1-2 hrs
# 2                20.0           20 seconds
# 3                20.0             1/2 hour
# 4               900.0           15 minutes
#
#                                             comments date posted   latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21  53.200000
# 3  My older brother and twin sister were leaving ...  2004-01-17  28.978333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.418056
#
#     longitude  state_check  country_check
# 0  -97.941111        False          False
# 1  -98.581082        False           True
# 2   -2.916667         True          False
# 3  -96.645833        False          False
# 4 -157.803611        False          False

# %%
dataframe.groupby(['country_check']).size().sort_values()
# Out:
# country_check
# True     12365
# False    76314
# dtype: int64

# %%
m_df = pd.merge(dataframe,final, on=['datetime','city','duration (seconds)','state','shape','duration (hours/min)','comments','date posted','latitude','longitude','state_check'],how='left')
m_df.head(5)
# Out:
#              datetime                  city state country_x     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx        us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx       NaN     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN        gb    circle
# 3 1956-10-10 21:00:00                  edna    tx        us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi        us     light
#
#    duration (seconds) duration (hours/min)  \
# 0              2700.0           45 minutes
# 1              7200.0              1-2 hrs
# 2                20.0           20 seconds
# 3                20.0             1/2 hour
# 4               900.0           15 minutes
#
#                                             comments date posted   latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21  53.200000
# 3  My older brother and twin sister were leaving ...  2004-01-17  28.978333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.418056
#
#     longitude  state_check  country_check_x country_y country_check_y
# 0  -97.941111        False            False       NaN             NaN
# 1  -98.581082        False             True       NaN             NaN
# 2   -2.916667         True            False       NaN             NaN
# 3  -96.645833        False            False       NaN             NaN
# 4 -157.803611        False            False       NaN             NaN

# %%
m_df.groupby(['country_check_x']).size().sort_values()
# Out:
# country_check_x
# True     12365
# False    76314
# dtype: int64

# %%
m_df['country_x'] = m_df['country_x'].mask(m_df['country_check_y'] == False,m_df['country_y'])

# %%
m_df = m_df.drop(columns=['state_check','country_check_x','country_y','country_check_y'])
m_df = m_df.rename(columns={'country_x':'country'})
m_df.head(5)
# Out:
#              datetime                  city state country     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3 1956-10-10 21:00:00                  edna    tx      us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi      us     light
#
#    duration (seconds) duration (hours/min)  \
# 0              2700.0           45 minutes
# 1              7200.0              1-2 hrs
# 2                20.0           20 seconds
# 3                20.0             1/2 hour
# 4               900.0           15 minutes
#
#                                             comments date posted   latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21  53.200000
# 3  My older brother and twin sister were leaving ...  2004-01-17  28.978333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.418056
#
#     longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
m_df['country_check'] = m_df['country'].isnull()
m_df['state_check'] = m_df['state'].isnull()
m_df.head(5)
# Out:
#              datetime                  city state country     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3 1956-10-10 21:00:00                  edna    tx      us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi      us     light
#
#    duration (seconds) duration (hours/min)  \
# 0              2700.0           45 minutes
# 1              7200.0              1-2 hrs
# 2                20.0           20 seconds
# 3                20.0             1/2 hour
# 4               900.0           15 minutes
#
#                                             comments date posted   latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21  53.200000
# 3  My older brother and twin sister were leaving ...  2004-01-17  28.978333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.418056
#
#     longitude  country_check  state_check
# 0  -97.941111          False        False
# 1  -98.581082           True        False
# 2   -2.916667          False         True
# 3  -96.645833          False        False
# 4 -157.803611          False        False

# %%
m_df_2 = m_df.copy()
m_df = m_df[m_df['country_check']== False]
m_df_2 = m_df_2[m_df_2['country_check']== True]

# %%
m_df_2['country'] = m_df_2['country'].mask(m_df_2['state_check']==False,'us')
m_df_2.head(5)
# Out:
#               datetime            city state country     shape  \
# 1  1949-10-10 21:00:00    lackland afb    tx      us     light
# 18 1973-10-10 23:00:00     bermuda nas   NaN     NaN     light
# 19 1974-10-10 17:00:00    willow beach    az      us     light
# 41 1986-10-10 20:00:00  holmes/pawling    ny      us   chevron
# 49 1989-10-10 21:00:00        kranklin    ky      us  triangle
#
#     duration (seconds) duration (hours/min)  \
# 1               7200.0              1-2 hrs
# 18                20.0              20 sec.
# 19               120.0                2 min
# 41               180.0            3 minutes
# 49               180.0                 3min
#
#                                              comments date posted   latitude  \
# 1   1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 18  saw fast moving blip on the radar scope thin w...  2002-01-11  32.364167
# 19  The object was a brillant white light standing...  2001-02-18   0.000000
# 41  Football Field Sized Chevron with bright white...  2007-10-08  41.523427
# 49        Triangle seen in franklin Ky - october 1989  2005-05-11  36.722263
#
#     longitude  country_check  state_check
# 1  -98.581082           True        False
# 18 -64.678611           True         True
# 19   0.000000           True        False
# 41 -73.646795           True        False
# 49 -86.577218           True        False

# %%
m_df = pd.concat([m_df,m_df_2])
m_df.head(10)
# Out:
#               datetime                  city state country     shape  \
# 0  1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 2  1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3  1956-10-10 21:00:00                  edna    tx      us    circle
# 4  1960-10-10 20:00:00               kaneohe    hi      us     light
# 5  1961-10-10 19:00:00               bristol    tn      us    sphere
# 6  1965-10-10 21:00:00    penarth (uk/wales)   NaN      gb    circle
# 7  1965-10-10 23:45:00               norwalk    ct      us      disk
# 8  1966-10-10 20:00:00             pell city    al      us      disk
# 9  1966-10-10 21:00:00              live oak    fl      us      disk
# 10 1968-10-10 13:00:00             hawthorne    ca      us    circle
#
#     duration (seconds) duration (hours/min)  \
# 0               2700.0           45 minutes
# 2                 20.0           20 seconds
# 3                 20.0             1/2 hour
# 4                900.0           15 minutes
# 5                300.0            5 minutes
# 6                180.0         about 3 mins
# 7               1200.0           20 minutes
# 8                180.0           3  minutes
# 9                120.0      several minutes
# 10               300.0               5 min.
#
#                                              comments date posted   latitude  \
# 0   This event took place in early fall around 194...  2004-04-27  29.883056
# 2   Green/Orange circular disc over Chester&#44 En...  2008-01-21  53.200000
# 3   My older brother and twin sister were leaving ...  2004-01-17  28.978333
# 4   AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.418056
# 5   My father is now 89 my brother 52 the girl wit...  2007-04-27  36.595000
# 6   penarth uk  circle  3mins  stayed 30ft above m...  2006-02-14  51.434722
# 7   A bright orange color changing to reddish colo...  1999-10-02  41.117500
# 8   Strobe Lighted disk shape object observed clos...  2009-03-19  33.586111
# 9   Saucer zaps energy from powerline as my pregna...  2005-05-11  30.294722
# 10  ROUND &#44 ORANGE &#44 WITH WHAT I WOULD SAY W...  2003-10-31  33.916389
#
#      longitude  country_check  state_check
# 0   -97.941111          False        False
# 2    -2.916667          False         True
# 3   -96.645833          False        False
# 4  -157.803611          False        False
# 5   -82.188889          False        False
# 6    -3.180000          False         True
# 7   -73.408333          False        False
# 8   -86.286111          False        False
# 9   -82.984167          False        False
# 10 -118.351667          False        False

# %%
m_df = m_df.sort_index()

# %%
m_df.head(5)
# Out:
#              datetime                  city state country     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx      us     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3 1956-10-10 21:00:00                  edna    tx      us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi      us     light
#
#    duration (seconds) duration (hours/min)  \
# 0              2700.0           45 minutes
# 1              7200.0              1-2 hrs
# 2                20.0           20 seconds
# 3                20.0             1/2 hour
# 4               900.0           15 minutes
#
#                                             comments date posted   latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21  53.200000
# 3  My older brother and twin sister were leaving ...  2004-01-17  28.978333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.418056
#
#     longitude  country_check  state_check
# 0  -97.941111          False        False
# 1  -98.581082           True        False
# 2   -2.916667          False         True
# 3  -96.645833          False        False
# 4 -157.803611          False        False

# %%
m_df['country_check'] = m_df['country'].isnull()

# %%
m_df.groupby(['country_check']).size()
# Out:
# country_check
# False    87560
# True      1119
# dtype: int64

# %%
m_df = m_df.drop(columns=['country_check','state_check'])

# %%
m_df.groupby(['shape']).size()
# Out:
# shape
# changed          1
# changing      2140
# chevron       1007
# cigar         2241
# circle        8453
# cone           367
# crescent         2
# cross          265
# cylinder      1382
# delta            8
# diamond       1308
# disk          6005
# dome             1
# egg            845
# fireball      6562
# flare            1
# flash         1472
# formation     2657
# hexagon          1
# light        17872
# other         6247
# oval          4119
# pyramid          1
# rectangle     1418
# round            2
# sphere        5755
# teardrop       817
# triangle      8489
# unknown       6319
# dtype: int64

# %%
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'flare','light')
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'round','sphere')
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'delta','triangle')
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'pyramid','triangle')
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'changed','changing')
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'disk','circle')
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'flash','light')
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'teardrop','oval')
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'egg','oval')
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'unknown','other')
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'hexagon','other')
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'crescent','other')
m_df['shape'] = m_df['shape'].mask(m_df['shape'] == 'dome','other')

# %%
m_df.groupby(['shape']).size()
# Out:
# shape
# changing      2141
# chevron       1007
# cigar         2241
# circle       14458
# cone           367
# cross          265
# cylinder      1382
# diamond       1308
# fireball      6562
# formation     2657
# light        19345
# other        12570
# oval          5781
# rectangle     1418
# sphere        5757
# triangle      8498
# dtype: int64

# %%
m_df['shape_check'] = m_df['shape'].isnull()
m_df.groupby(['shape_check']).size()
# Out:
# shape_check
# False    85757
# True      2922
# dtype: int64

# %%
m_df['shape'] = m_df['shape'].mask(m_df['shape_check'] == True,'other')
m_df['shape_check'] = m_df['shape'].isnull()
m_df.groupby(['shape_check']).size()
# Out:
# shape_check
# False    88679
# dtype: int64

# %%
m_df = m_df.drop(columns=['shape_check'])
m_df.head(5)
# Out:
#              datetime                  city state country     shape  \
# 0 1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1 1949-10-10 21:00:00          lackland afb    tx      us     light
# 2 1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3 1956-10-10 21:00:00                  edna    tx      us    circle
# 4 1960-10-10 20:00:00               kaneohe    hi      us     light
#
#    duration (seconds) duration (hours/min)  \
# 0              2700.0           45 minutes
# 1              7200.0              1-2 hrs
# 2                20.0           20 seconds
# 3                20.0             1/2 hour
# 4               900.0           15 minutes
#
#                                             comments date posted   latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21  53.200000
# 3  My older brother and twin sister were leaving ...  2004-01-17  28.978333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.418056
#
#     longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
m_df = m_df.rename(columns={'datetime':'observation_datestamp','country':'country_id','shape':'shape_type','duration (seconds)':'duration_in_sec','duration (hours/min)':'duration_string','state':'state_id','date posted':'date_posted'})
m_df.head(5)
# Out:
#   observation_datestamp                  city state_id country_id shape_type  \
# 0   1949-10-10 20:30:00            san marcos       tx         us   cylinder
# 1   1949-10-10 21:00:00          lackland afb       tx         us      light
# 2   1955-10-10 17:00:00  chester (uk/england)      NaN         gb     circle
# 3   1956-10-10 21:00:00                  edna       tx         us     circle
# 4   1960-10-10 20:00:00               kaneohe       hi         us      light
#
#    duration_in_sec duration_string  \
# 0           2700.0      45 minutes
# 1           7200.0         1-2 hrs
# 2             20.0      20 seconds
# 3             20.0        1/2 hour
# 4            900.0      15 minutes
#
#                                             comments date_posted   latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21  53.200000
# 3  My older brother and twin sister were leaving ...  2004-01-17  28.978333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.418056
#
#     longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611

# %%
m_df.to_csv(r'data/complete_cleaned.csv',sep=';')

# %%
m_df.to_parquet(r'data/complete_cleaned')

# %%
new_df = pd.read_parquet(r'data/complete_cleaned')
new_df.head(10)
# Out:
#   observation_datestamp                  city state_id country_id shape_type  \
# 0   1949-10-10 20:30:00            san marcos       tx         us   cylinder
# 1   1949-10-10 21:00:00          lackland afb       tx         us      light
# 2   1955-10-10 17:00:00  chester (uk/england)     None         gb     circle
# 3   1956-10-10 21:00:00                  edna       tx         us     circle
# 4   1960-10-10 20:00:00               kaneohe       hi         us      light
# 5   1961-10-10 19:00:00               bristol       tn         us     sphere
# 6   1965-10-10 21:00:00    penarth (uk/wales)     None         gb     circle
# 7   1965-10-10 23:45:00               norwalk       ct         us     circle
# 8   1966-10-10 20:00:00             pell city       al         us     circle
# 9   1966-10-10 21:00:00              live oak       fl         us     circle
#
#    duration_in_sec  duration_string  \
# 0           2700.0       45 minutes
# 1           7200.0          1-2 hrs
# 2             20.0       20 seconds
# 3             20.0         1/2 hour
# 4            900.0       15 minutes
# 5            300.0        5 minutes
# 6            180.0     about 3 mins
# 7           1200.0       20 minutes
# 8            180.0       3  minutes
# 9            120.0  several minutes
#
#                                             comments date_posted   latitude  \
# 0  This event took place in early fall around 194...  2004-04-27  29.883056
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...  2005-12-16  29.384210
# 2  Green/Orange circular disc over Chester&#44 En...  2008-01-21  53.200000
# 3  My older brother and twin sister were leaving ...  2004-01-17  28.978333
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...  2004-01-22  21.418056
# 5  My father is now 89 my brother 52 the girl wit...  2007-04-27  36.595000
# 6  penarth uk  circle  3mins  stayed 30ft above m...  2006-02-14  51.434722
# 7  A bright orange color changing to reddish colo...  1999-10-02  41.117500
# 8  Strobe Lighted disk shape object observed clos...  2009-03-19  33.586111
# 9  Saucer zaps energy from powerline as my pregna...  2005-05-11  30.294722
#
#     longitude
# 0  -97.941111
# 1  -98.581082
# 2   -2.916667
# 3  -96.645833
# 4 -157.803611
# 5  -82.188889
# 6   -3.180000
# 7  -73.408333
# 8  -86.286111
# 9  -82.984167

# %%
new_df.dtypes
# Out:
# observation_datestamp    datetime64[ns]
# city                             object
# state_id                         object
# country_id                       object
# shape_type                       object
# duration_in_sec                 float64
# duration_string                  object
# comments                         object
# date_posted              datetime64[ns]
# latitude                        float64
# longitude                       float64
# dtype: object
